# %%
from src.modeling.prediction_cnn import PredictionCNN
from src.utils.l import PredictionCNN
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/tobiaochsner/Documents/ETH/GeneticFitness/notebooks/NN validation.ipynb Cell 1 line 2
#       <a href='vscode-notebook-cell:/Users/tobiaochsner/Documents/ETH/GeneticFitness/notebooks/NN%20validation.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> from src.modeling.prediction_cnn import PredictionCNN
# ----> <a href='vscode-notebook-cell:/Users/tobiaochsner/Documents/ETH/GeneticFitness/notebooks/NN%20validation.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> from src.utils.l import PredictionCNN
#
# ModuleNotFoundError: No module named 'src.utils.l'

# %%
PredictionCNN.load_from_checkpoint("../models/basic_cnn/epoch=10-val_loss=0.20.ckpt")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/tobiaochsner/Documents/ETH/GeneticFitness/notebooks/NN validation.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/Users/tobiaochsner/Documents/ETH/GeneticFitness/notebooks/NN%20validation.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> PredictionCNN.load_from_checkpoint("../models/basic_cnn/epoch=10-val_loss=0.20.ckpt")
#
# NameError: name 'PredictionCNN' is not defined

# %%
import pandas as pd
import numpy as np
from scipy import stats

# %%
results = pd.read_csv("/Users/tobiaochsner/Documents/ETH/GeneticFitness/data/output/with_factors.csv")

# %%
np.mean((results.fitness - results.prediction).apply(lambda y: y**2))
# Out:
# 0.2032467147563711

# %%
stats.spearmanr(
    results.fitness,
    results.prediction
)
# Out:
# SignificanceResult(statistic=0.5282880488640472, pvalue=4.185679285175831e-298)

# %%
results[['fitness', 'prediction']].plot.scatter(x='fitness', y='prediction')
# Out:
# <Axes: xlabel='fitness', ylabel='prediction'>
